# %% [markdown]
# ## We used BERT for processing repos readme, description and name. Then we used k-means and dendrogram for unsupervised learning. To run this code, we need to import what we have extracted, which is the file named "ethereum_repos_extracted_text_cleaned.json"

# %%
! pip install spacy
! python -m spacy download en_core_web_sm
! pip install gensim
! pip install scikit-learn
! pip install transformers torch
! pip install kneed
! pip install scipy matplotlib

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize
import smart_open
from gensim.parsing.preprocessing import strip_punctuation, remove_stopwords
from transformers import BertModel, BertTokenizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import spacy
import torch
import re
import json
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
# use spacy for text preprocessing
spacy.cli.download('en_core_web_sm')

nlp = spacy.load('en_core_web_sm')

json_file_path = '/content/ethereum_repos_extracted_text_cleaned.json'

with open(json_file_path, 'r') as file:
  json_data = json.load(file)

l = list()
for repo in json_data:

  text = repo["name"]+" " + (repo["desc"] or " ")+ " " + (repo["readme"] or " ")
  text = remove_stopwords(strip_punctuation(text))
  l.append(text)

# %%
# use "bert-base-uncased" for embedding
model_name = 'bert-base-uncased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)

inputs = tokenizer(l, padding=True, truncation=True, max_length=128, return_tensors="pt")

with torch.no_grad():
    outputs = model(**inputs)
    embeddings = outputs.last_hidden_state.mean(dim=1).numpy()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
# used elbow method for determining the number of clusters
wcss = []
for i in range(2, 12):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=1000, n_init=10, random_state=0)
    kmeans.fit(embeddings)
    wcss.append(kmeans.inertia_)
plt.bar(range(2, 12), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# find knee point to precisely determine cluster number
from kneed import KneeLocator

k_values = list(range(2, 12))

kneedle = KneeLocator(k_values, wcss, curve='convex', direction='decreasing')

elbow_point = kneedle.elbow

print(f"The elbow point is at cluster number: {elbow_point}")
# Out:
# The elbow point is at cluster number: 6

# %%
# # PCA for dimentionality reduction for visualization
# num_clusters = 6
# kmeans = KMeans(n_clusters=num_clusters, random_state=42)
# kmeans.fit(embeddings)
# labels = kmeans.labels_

# pca = PCA(n_components=2)
# reduced_embeddings = pca.fit_transform(embeddings)

# plt.figure(figsize=(8, 6))
# for i in range(num_clusters):
#   plt.scatter(reduced_embeddings[labels == i, 0], reduced_embeddings[labels == i, 1], label=f"Cluster {i+1}")

# for index, coord in enumerate(reduced_embeddings):
#   x = coord[0]
#   y = coord[1]
#   plt.text(x, y, json_data[index]["name"], va='bottom', ha='center', fontdict={'size': 2})

# plt.title("Text Data Clustering with BERT Embeddings")
# plt.legend()
# plt.savefig("textdata.pdf")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import json

# Assuming 'embeddings' is your array of BERT embeddings and 'json_data' contains your text data
num_clusters = 6
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(embeddings)
labels = kmeans.labels_

# Use t-SNE for dimensionality reduction
tsne = TSNE(n_components=2, random_state=42)
reduced_embeddings = tsne.fit_transform(embeddings)

# Plotting
plt.figure(figsize=(8, 6))
for i in range(num_clusters):
    plt.scatter(reduced_embeddings[labels == i, 0], reduced_embeddings[labels == i, 1], label=f"Cluster {i+1}")

for index, coord in enumerate(reduced_embeddings):
    x = coord[0]
    y = coord[1]
    plt.text(x, y, json_data[index]["name"], va='bottom', ha='center', fontdict={'size': 2})

plt.title("Text Data Clustering with BERT Embeddings using t-SNE")
plt.legend()
plt.savefig("textdata_tsne.pdf")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import pandas as pd

# Convert json_data to a DataFrame
data_df = pd.DataFrame(json_data)

# Add the cluster labels to the DataFrame
data_df['cluster'] = labels

# Create a list to hold the data for each cluster
clustered_list = []

# Group the DataFrame by the 'cluster' column and list the names
for cluster_number in range(num_clusters):
    cluster_data = data_df[data_df['cluster'] == cluster_number]['name'].tolist()
    clustered_list.append({'Cluster': cluster_number, 'Names': cluster_data})

# Now create the DataFrame from the list
clustered_data = pd.DataFrame(clustered_list)

# Display the DataFrame
print(clustered_data.to_string(index=False))

# If you want to save this DataFrame to a CSV file
clustered_data.to_csv('clustered_data.csv', index=False)
# Out:
#  Cluster                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Names
#        0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [cpp-ethash, dapp-bin, deposit_contract, economic-modeling, ethdev-site, ethendance, go-casper, grants-advisors, homestead-guide, kzg-ceremony-sequencer, mining, news, plasma, profiling, pyethapp, pyeth_keys, remix-theia, remix-website, scavenger_hunt, solidity-fuzzing-corpus, solidity.js, testng, trinity-web]
#        1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [casper, common, cpp-build-env, cpp-dependencies-win64, cryptopp, devops-test-prater-redirect, docker-pyeth-dev, emacs-solidity, eth-typeshed, eth-wiki-test, eth2.0-onboarding, ethereum-dockers, ethereum-ppa, fuzzertests, gav, genesis_block_generator, hunter-cache, libwhisper, populus, portal-spec-tests, pos-evolution, pydevp2p, py_pairing, remix-tests, solidity-buildpack-deps, solidity-test-bytecode, vim-solidity]
#        2 [aleth, alethzero, awesome-remix, discv4-crawl, ens-registrar-dapp, eth-net-intelligence-api, eth-netstats, eth2-client-tests, ethereum-binaries, ethereum-buildbot, ethereum-client-binaries, ethereum-docs, ethereum-foundation-website, ethereum-org, ethereum-org-fork, ethereum-org-website, ethereum-react-components, fellowship-program-website, foundation-archived, fv-blog, GitSync, glados, go-ethereum, grid, grid-ui, guide, hive, homebrew-ethereum, jenkins-docker, local-testnet, mantis-apache2, meteor-dapp-catalog, meteor-dapp-wallet, meteor-dapp-whisper-chat-client, meteor-ethereum-networkinfo, meteor-package-accounts, mist, mix, moon-browser, node-crawler, oyente, portal-blog, remix, remix-desktop, remix-ide, remix-live-beta, remix-plugin, remix-plugins-directory, remix-project, remix-vscode, remix-workshops, remixd, secure-drop, solc-bin, solidity-website, staking-launchpad, swarm-dapps, system-testing, testeth, trin, tryethereum, webthree-umbrella, www, yellowpaper]
#        3                                                                                                                                                              [abm1559, act, annotated-spec, beacon-APIs, beaconrunner, bls12-381-tests, btcrelay, builder-specs, c-kzg-4844, clrfund, consensus-spec-tests, consensus-specs, cryptography-research-website, devp2p, distributed-validator-specs, EIPs, eipv, eip_validator, ens-namehash-py, ERCs, esp-website, eth-keyfile, eth-keys, eth-tester, eth2.0-pm, eth2.0-tests, ethereum-console, ethereumj, evmc, evmcodegen, evmdasm, evmone, execution-apis, execution-spec-tests, execution-specs, fe, hevm, hexbytes, js-ethereum-cryptography, keymanager-APIs, kzg-ceremony, kzg-ceremony-specs, lahja, libsnark, pm, portal-accumulators, portal-network-specs, public-attacknets, public-disclosures, py-evm, pyethsaletool, py_ecc, rayonism, remote-signing-api, rig, solidity, solidity-examples, sourcify, statesweep, tests, UniversalLoginSDK, yul-isabelle]
#        4                                                                                                                                                                                                                [beacon-metrics, beacon_chain, bench, benchmarking, browser-solidity, cpp-dependencies, cpp-ethereum-cmake, devcommon, diary, discv4-dns-lists, ecp, eip-review-bot, eth-wiki, ethash, ethereum.org, ethsim, frontier-guide, geth-website, gethkey, go-verkle, interfaces, js-team-organization, langlab, legacytests, libethereum, libweb3core, node-ethereum, play, portal-hive, portal-website, pyethereum, remix-live, remix-live-alpha, requests-for-proposals, research, RIPs, ropsten, serpent-go, sharding, simplecasper, snake-charmers-blog, snake-charmers-tactical-manual, solidity-blog, solidity-portal, solidity-summit, solidity-underhanded-contest, stake-voice, tlsnotary-old-website, trinity, trinity-eth2, verkle-dev-website, web3.py, webthree, webthree-helpers, whisper, wiki]
#        5                                                                                         [aio-run-in-process, alexandria, async-service, asyncio-cancel-token, asyncio-run-in-process, bimini, blake2b-py, blockies, cable, cbc-casper, clef-ui, consensus-deployment-ansible, cthaeh, dapp-styles, ddht, dopple, EIP-Bot, eipw, eipw-action, eth-abi, eth-account, eth-bloom, eth-enr, eth-hash, eth-orm, eth-portal, eth-rlp, eth-typing, eth-utils, eth2.0-test-generators, ethbot, ethereum-org-next, ethereum-python-project-template, evmjit, evmlab, go-build, kzg-ceremony-verifier, leveldb, merge-testnet-verifier, meteor-package-blocks, meteor-package-elements, meteor-package-tools, moon-lang, moon-tool, natspec.js, nodemonitor, py-geth, py-hdwallet, py-snappy, py-solc, py-ssz, py-trie, py-wasm, pyrlp, pytest-asyncio-network-simulator, pytest-ethereum, retesteth, rpc-tests, serpent, solc-js, ssv, staking-deposit-cli, test-tools, trio-run-in-process, twig, upnp-port-forward, utp, Yul-K]

# %%
# Plotting the dendrogram
Z = linkage(embeddings, 'ward')
plt.figure(figsize=(10, 7))
plt.title("Dendrogram")
fig, ax = plt.subplots()
repo_names = [repo["name"] for repo in json_data]
dendrogram(
    Z,
    labels=repo_names,
    leaf_rotation=90,
    leaf_font_size=2,
)
fig.tight_layout()
plt.savefig('/content/dendrogram.pdf')
plt.show()
