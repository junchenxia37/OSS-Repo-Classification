# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

orgs = [
    'python',
    'rust-lang',
    'golang',
    'torvalds/linux ',
    'apache',
    'mozilla',
    'sagemath',
    'kubernetes',
    'aws',
    'facebookresearch ',
    'google',
    'google-research ',
    'tensorflow',
    'openai',
    'zcash',
    'OffchainLabs',
    'ethereum-optimism',
    'Layr-Labs',
    'matter-labs',
    'solana-labs',
    'brave',
    'filecoin-project',
    'ipfs',
    'protocol',
    '0xPolygon',
    'cardano-foundation',
    'near',
    'stellar',
    'dashpay',
    'tezos',
    'algorand',
]

pinned_repos = {}

for org in orgs:
    url = f'https://github.com/{org}'
    response = requests.get(url)

    if response.status_code == 200:
        html_content = response.text
    else:
        print(f"Failed to retrieve the page {org}. Status code: {response.status_code}")
        continue

    soup = BeautifulSoup(html_content, 'html.parser')
    pinned = soup.find('div', class_='js-pinned-items-reorder-container')
    if pinned is None:
        print(f"No pinned found for {org}")
        continue
    repo_spans = pinned.find_all('span', class_='repo')

    pinned_repos[org] = [span.text.strip() for span in repo_spans]


new_dict = {"facebookresearch": ["segment-anything", "fairseq", "detectron2", "faiss", "Detectron", "fastText"], "google-research": ["google-research"],"torvalds":["linux"]}
pinned_repos.update(new_dict)

for org, repos in pinned_repos.items():
    print(f'{org}\t{repos}')


Information=[]
for org, repos in pinned_repos.items():
    org_df = pd.read_csv(f"{org}.csv")
    for repo in repos:
      specific_row_series = org_df[org_df['name'] == repo].squeeze()
      desc=specific_row_series["description"]
      each_tuple = (org, repo, desc)
      Information.append(each_tuple)
# Out:
# Failed to retrieve the page torvalds/linux . Status code: 404
# Failed to retrieve the page facebookresearch . Status code: 404
# Failed to retrieve the page google-research . Status code: 404
# python	['cpython', 'mypy', 'pythondotorg', 'peps', 'typeshed', 'devguide']
# rust-lang	['rust', 'cargo', 'rfcs']
# golang	['go']
# apache	['echarts', 'superset', 'dubbo', 'spark', 'airflow', 'kafka']
# mozilla	['pdf.js', 'DeepSpeech', 'send', 'BrowserQuest', 'TTS', 'nunjucks']
# sagemath	['sage', 'website', 'publications', 'sage-shell-mode', 'sagecell', 'sagetex']
# kubernetes	['kubernetes', 'enhancements', 'community', 'website', 'test-infra', 'examples']
# aws	['aws-cli', 'serverless-application-model', 'aws-cdk', 'amazon-sagemaker-examples', 's2n-tls', 'aws-sdk-go-v2']
# google	['material-design-icons', 'guava', 'zx', 'styleguide', 'leveldb', 'googletest']
# tensorflow	['tensorflow', 'docs', 'community']
# openai	['openai-cookbook', 'whisper', 'evals', 'openai-python', 'tiktoken', 'openai-node']
# zcash	['zcash', 'halo2', 'librustzcash', 'zips', 'mpc', 'libsnark']
# OffchainLabs	['nitro', 'token-bridge-contracts', 'arbitrum-sdk', 'arbitrum-tutorials', 'arbitrum-token-bridge', 'arbitrum-docs']
# ethereum-optimism	['optimism', 'specs', 'docs', 'community-hub', 'OPerating-manual', 'ecosystem-contributions']
# Layr-Labs	['eigenlayer-contracts', 'incredible-squaring-avs', 'eigenda', 'eigenda-operator-setup', 'eigenlayer-cli', 'eigenlayer-middleware']
# matter-labs	['zksync-era', 'era-contracts', 'era-sync_vm', 'awesome-zero-knowledge-proofs']
# solana-labs	['solana-program-library', 'solana']
# brave	['brave-browser', 'brave-core', 'adblock-rust', 'goggles-quickstart']
# filecoin-project	['community', 'FIPs', 'lotus', 'rust-fil-proofs', 'builtin-actors', 'ref-fvm']
# ipfs	['specs', 'ipfs', 'ipfs-desktop', 'ipfs-companion', 'kubo', 'helia']
# protocol	['arg', 'research', 'research-grants', 'ResNetLab']
# 0xPolygon	['polygon-edge', 'fx-portal', 'cdk-validium-node', 'chain-indexer-framework', 'polygon-docs', 'account-binary-search-tree']
# cardano-foundation	['CIPs']
# near	['nearcore', 'NEPs', 'core-contracts', 'near-api-js', 'create-near-app', 'near-cli-rs']
# stellar	['stellar-protocol', 'stellar-core', 'js-stellar-sdk', 'rs-soroban-sdk', 'soroban-rpc', 'soroban-cli']
# dashpay	['dash', 'platform', 'grovedb', 'tenderdash', 'dash-wallet', 'dashwallet-ios']
# tezos	['tezos-mirror']
# algorand	['go-algorand', 'js-algorand-sdk', 'pyteal', 'py-algorand-sdk', 'sandbox', 'go-algorand-sdk']

# %%
import pandas as pd


pinned_repos = {'python': ['cpython', 'mypy', 'pythondotorg', 'peps', 'typeshed', 'devguide'],
'rust-lang': ['rust', 'cargo', 'rfcs'],
'golang': ['go'],
'mozilla': ['pdf.js', 'DeepSpeech', 'send', 'BrowserQuest', 'TTS', 'nunjucks'],
'sagemath': ['sage', 'website', 'publications', 'sage-shell-mode', 'sagecell', 'sagetex'],
'kubernetes': ['kubernetes', 'enhancements', 'community', 'website', 'test-infra', 'examples'],
'aws': ['aws-cli', 'serverless-application-model', 'aws-cdk', 'amazon-sagemaker-examples', 's2n-tls', 'aws-sdk-go-v2'],
'google': ['material-design-icons', 'guava', 'zx', 'styleguide', 'leveldb', 'googletest'],
'tensorflow': ['tensorflow', 'docs', 'community'],
'openai': ['openai-cookbook', 'whisper', 'evals', 'openai-python', 'tiktoken', 'openai-node'],
'zcash': ['zcash', 'halo2', 'librustzcash', 'zips', 'mpc', 'libsnark'],
'OffchainLabs': ['nitro', 'token-bridge-contracts', 'arbitrum-sdk', 'arbitrum-tutorials', 'arbitrum-token-bridge', 'arbitrum-docs'],
'ethereum-optimism': ['optimism', 'specs', 'docs', 'community-hub', 'OPerating-manual', 'ecosystem-contributions'],
'Layr-Labs': ['eigenlayer-contracts', 'incredible-squaring-avs', 'eigenda', 'eigenda-operator-setup', 'eigenlayer-cli', 'eigenlayer-middleware'],
'matter-labs': ['zksync-era', 'era-contracts', 'era-sync_vm', 'awesome-zero-knowledge-proofs'],
'solana-labs': ['solana-program-library', 'solana'],
'brave': ['brave-browser', 'brave-core', 'adblock-rust', 'goggles-quickstart'],
'filecoin-project': ['community', 'FIPs', 'lotus', 'rust-fil-proofs', 'builtin-actors', 'ref-fvm'],
'ipfs': ['specs', 'ipfs', 'ipfs-desktop', 'ipfs-companion', 'kubo', 'helia'],
'protocol': ['arg', 'research', 'research-grants', 'ResNetLab'],
'0xPolygon': ['polygon-edge', 'fx-portal', 'cdk-validium-node', 'chain-indexer-framework', 'polygon-docs', 'account-binary-search-tree'],
'cardano-foundation': ['CIPs'],
'near': ['nearcore', 'NEPs', 'core-contracts', 'near-api-js', 'create-near-app', 'near-cli-rs'],
'stellar': ['stellar-protocol', 'stellar-core', 'js-stellar-sdk', 'rs-soroban-sdk', 'soroban-rpc', 'soroban-cli'],
'dashpay': ['dash', 'platform', 'grovedb', 'tenderdash', 'dash-wallet', 'dashwallet-ios'],
'tezos': ['tezos-mirror'],
'algorand': ['go-algorand', 'js-algorand-sdk', 'pyteal', 'py-algorand-sdk', 'sandbox', 'go-algorand-sdk'], }

new_dict = {"facebookresearch": ["segment-anything", "fairseq", "detectron2", "faiss", "Detectron", "fastText"], "google-research": ["google-research"],"linux":["linux"]}
pinned_repos.update(new_dict)

for org, repos in pinned_repos.items():
    print(f'{org}\t{repos}')


Information=[]
for org, repos in pinned_repos.items():
    org_df = pd.read_csv(f"{org}.csv")
    for repo in repos:
      specific_row_series = org_df[org_df['name'] == repo].squeeze()
      desc=specific_row_series["description"]
      each_tuple = (org, repo, desc)
      Information.append(each_tuple)
# Out:
# python	['cpython', 'mypy', 'pythondotorg', 'peps', 'typeshed', 'devguide']
# rust-lang	['rust', 'cargo', 'rfcs']
# golang	['go']
# mozilla	['pdf.js', 'DeepSpeech', 'send', 'BrowserQuest', 'TTS', 'nunjucks']
# sagemath	['sage', 'website', 'publications', 'sage-shell-mode', 'sagecell', 'sagetex']
# kubernetes	['kubernetes', 'enhancements', 'community', 'website', 'test-infra', 'examples']
# aws	['aws-cli', 'serverless-application-model', 'aws-cdk', 'amazon-sagemaker-examples', 's2n-tls', 'aws-sdk-go-v2']
# google	['material-design-icons', 'guava', 'zx', 'styleguide', 'leveldb', 'googletest']
# tensorflow	['tensorflow', 'docs', 'community']
# openai	['openai-cookbook', 'whisper', 'evals', 'openai-python', 'tiktoken', 'openai-node']
# zcash	['zcash', 'halo2', 'librustzcash', 'zips', 'mpc', 'libsnark']
# OffchainLabs	['nitro', 'token-bridge-contracts', 'arbitrum-sdk', 'arbitrum-tutorials', 'arbitrum-token-bridge', 'arbitrum-docs']
# ethereum-optimism	['optimism', 'specs', 'docs', 'community-hub', 'OPerating-manual', 'ecosystem-contributions']
# Layr-Labs	['eigenlayer-contracts', 'incredible-squaring-avs', 'eigenda', 'eigenda-operator-setup', 'eigenlayer-cli', 'eigenlayer-middleware']
# matter-labs	['zksync-era', 'era-contracts', 'era-sync_vm', 'awesome-zero-knowledge-proofs']
# solana-labs	['solana-program-library', 'solana']
# brave	['brave-browser', 'brave-core', 'adblock-rust', 'goggles-quickstart']
# filecoin-project	['community', 'FIPs', 'lotus', 'rust-fil-proofs', 'builtin-actors', 'ref-fvm']
# ipfs	['specs', 'ipfs', 'ipfs-desktop', 'ipfs-companion', 'kubo', 'helia']
# protocol	['arg', 'research', 'research-grants', 'ResNetLab']
# 0xPolygon	['polygon-edge', 'fx-portal', 'cdk-validium-node', 'chain-indexer-framework', 'polygon-docs', 'account-binary-search-tree']
# cardano-foundation	['CIPs']
# near	['nearcore', 'NEPs', 'core-contracts', 'near-api-js', 'create-near-app', 'near-cli-rs']
# stellar	['stellar-protocol', 'stellar-core', 'js-stellar-sdk', 'rs-soroban-sdk', 'soroban-rpc', 'soroban-cli']
# dashpay	['dash', 'platform', 'grovedb', 'tenderdash', 'dash-wallet', 'dashwallet-ios']
# tezos	['tezos-mirror']
# algorand	['go-algorand', 'js-algorand-sdk', 'pyteal', 'py-algorand-sdk', 'sandbox', 'go-algorand-sdk']
# facebookresearch	['segment-anything', 'fairseq', 'detectron2', 'faiss', 'Detectron', 'fastText']
# google-research	['google-research']
# linux	['linux']

# %%
# !pip3 install -q openai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.5 MB/s eta 0:00:00

# %%
from openai import OpenAI

# %%
print(len(Information))
# Out:
# 139

# %%
#############################################################
### without org name provided, feed in repo names and description

###results: not entirely based on original orgs
#############################################################

client = OpenAI(api_key='xxxxxxxxxxx')

instruction = '''Based on the content provided, group all repositories into some clusters and provide a short definition of each cluster. Note that each cluster should contain more than 1 repository. In addition, the topics of repositories in the cluster should be as similar as possible.The repositories are primarily software development repositories.'''

messages = [
      {"role": "system", "content": instruction},
  ]

# Build the prompt to integrate all repo descriptions into it'''

messages = [
      {"role": "system", "content": instruction},
  ]

# Build the prompt to integrate all repo descriptions into it
prompt = ''

for idx, item in enumerate(Information):
  prompt = prompt + f'{item[1]}:{item[2]}\n'

# prompt: 'these are ... repo 1 desc is ...; repo 2 ...'
messages.append({"role": "user", 'content': prompt})
completion = client.chat.completions.create(
  model="gpt-4",
  messages=messages,
  seed = 3407
)

import pickle

with open('completion', 'wb') as f:
  pickle.dump(completion, f)

print(completion.choices[0].message.content)
# Out:
# Cluster 1: Python Development
# - Repositories : cpython, mypy, pythondotorg, peps, typeshed, devguide
# - Definition: Python language source code, documentation, development resources, and improvement proposals
#
# Cluster 2: Rust Development
# - Repositories : rust, cargo, rfcs
# - Definition: Rust language, its package manager, and RFCs for Rust changes
#
# Cluster 3: JavaScript/TypeScript Development
# - Repositories : pdf.js, DeepSpeech, send, BrowserQuest, TTS, nunjucks
# - Definition: Various JavaScript and TypeScript libraries and tools including PDF reader, speech-to-text engine, file sharing, and multiplayer game experiment
#
# Cluster 4: SageMath Development
# - Repositories : sage, website, publications, sage-shell-mode, sagecell, sagetex
# - Definition: Main SageMath repository, website source code, and tools supporting SageMath computations
#
# Cluster 5: Kubernetes Development
# - Repositories : kubernetes, enhancements, community, website, test-infra, examples
# - Definition: Kubernetes container scheduling and management, with enhancements, community content, website, and test infrastructure
#
# Cluster 6: Amazon Web Services Development
# - Repositories : aws-cli, serverless-application-model, aws-cdk, amazon-sagemaker-examples, s2n-tls, aws-sdk-go-v2
# - Definition: AWS tools and example codes for managing services, building serverless applications, developing cloud infrastructure, etc.
#
# Cluster 7: Google Open Source Projects
# - Repositories : material-design-icons, guava, zx, styleguide, leveldb, googletest
# - Definition: Open source projects from Google, including icons, Java libraries, script writing tools, style guides and testing frameworks.
#
# Cluster 8: TensorFlow and Machine Learning Frameworks
# - Repositories : tensorflow, docs, community
# - Definition: TensorFlow machine learning framework, its documentation and community content
#
# Cluster 9: OpenAI API and Tools
# - Repositories : openai-cookbook, whisper, evals, openai-python, tiktoken, openai-node
# - Definition: Libraries, example codes, and tools for OpenAI API
#
# Cluster 10: ZCash and Cryptocurrency Development
# - Repositories : zcash, halo2, librustzcash, zips, mpc, libsnark
# - Definition: Source code and enhancement proposals for ZCash cryptocurrency, including libraries and proofs
#
# Cluster 11: Web Development and Design
# - Repositories: material-design-icons, nunjucks
# - Definition: Various resources for web design and development, including icons and template engine tools.
#
# Cluster 12: IPFS Protocol
#  - Repositories: specs, ipfs, ipfs-desktop, ipfs-companion, kubo, helia
#  - Definition: Various tools, implementations, and resources for the InterPlanetary File System (IPFS) protocol.
#
# Cluster 13: Cryptocurrency and Blockchain Technologies
#  - Repositories: nitro, token-bridge-contracts, arbitrum-sdk, arbitrum-tutorials, arbitrum-token-bridge, arbitrum-docs,
#    optimism, specs, docs, community-hub, OPerating-manual, ecosystem-contributions, eigenlayer-contracts,
#    incredible-squaring-avs, eigenda, eigenda-operator-setup, eigenlayer-cli, eigenlayer-middleware, zksync-era,
#    era-contracts, era-sync_vm, awesome-zero-knowledge-proofs, solana-program-library, solana, brave-browser,
#    brave-core, adblock-rust, goggles-quickstart, community, FIPs, lotus, rust-fil-proofs, builtin-actors,
#    ref-fvm, polygon-edge, fx-portal, cdk-validium-node, chain-indexer-framework, polygon-docs,
#    account-binary-search-tree, CIPs, nearcore, NEPs, core-contracts, near-api-js, create-near-app, near-cli-rs,
#    stellar-protocol, stellar-core, js-stellar-sdk, rs-soroban-sdk, soroban-rpc, soroban-cli, dash, platform,
#    grovedb, tenderdash, dash-wallet, dashwallet-ios, tezos-mirror, go-algorand, js-algorand-sdk, pyteal,
#    py-algorand-sdk, sandbox, go-algorand-sdk.
#  - Definition: A large variety of repositories related to the development of different cryptocurrencies and blockchain based technologies or related protocols.
#
# Cluster 14: Google and Facebook AI Research
#  - Repositories: segment-anything, fairseq, detectron2, faiss, Detectron, fastText, google-research
#  - Definition: AI research projects and tools from Google and Facebook, including fast text representation, similarity search library and object detection research platform.
#
# Cluster 15: Linux Kernel Development
#  - Repository: linux
#  - Definition: Source code for the Linux kernel.

# %%
############################################################
### with org name provided

###results: based on original orgs
###########################################################

client = OpenAI(api_key='xxxxxxxxxx')

instruction = '''Based on the content provided, group all repositories into some clusters and provide a short definition of each cluster. Note that each cluster should contain more than 1 repository. In addition, the topics of repositories in the cluster should be as similar as possible.The repositories are primarily software development repositories.'''

messages = [
      {"role": "system", "content": instruction},
  ]

# Build the prompt to integrate all repo descriptions into it'''

messages = [
      {"role": "system", "content": instruction},
  ]

# Build the prompt to integrate all repo descriptions into it
prompt = ''

for idx, item in enumerate(Information):
  prompt = prompt + f'{item[1]}:{item[2]} and it is under organization named {item[0]}'

# prompt: 'these are ... repo 1 desc is ...; repo 2 ...'
messages.append({"role": "user", 'content': prompt})
completion = client.chat.completions.create(
  model="gpt-4",
  messages=messages,
  seed = 3407
)

import pickle

with open('completion', 'wb') as f:
  pickle.dump(completion, f)

print(completion.choices[0].message.content)
# Out:
# Cluster 1 - Python Programming:
# This cluster includes projects such as cpython, mypy, pythondotorg, peps, typeshed, and devguide all from Python organization. These repositories are focused on the Python programming language and its documentation, usage, and development guides.
#
# Cluster 2 - Rust Programming:
# This cluster includes repositories like rust and cargo from Rust-Lang organization. These repositories are focused on Rust programming language and its package manager.
#
# Cluster 3 - Go Programming:
# This cluster includes repositories like go from Golang organization. These repositories are centered around development and enhancements in the Go programming language.
#
# Cluster 4 - Mozilla:
# Repositories like pdf.js, DeepSpeech, send, BrowserQuest, TTS, and nunjucks under Mozilla organization make up this cluster. These projects revolve around various software and tools developed by Mozilla.
#
# Cluster 5 - SageMath:
# This cluster includes repositories such as sage, website, publications, sage-shell-mode, sagecell, sagetex, and sage from Sagemath organization. These repositories are dedicated to the SageMath software and related components.
#
# Cluster 6 - Kubernetes:
# This cluster includes repositories such as kubernetes, enhancements, community, website, test-infra, and examples under the Kubernetes organization. These repositories deal with the production and development of Kubernetes.
#
# Cluster 7 - AWS:
# This cluster includes aws-cli, serverless-application-model, aws-cdk, amazon-sagemaker-examples, s2n-tls, aws-sdk-go-v2 under AWS organization. All of these projects are tools or libraries for Amazon Web Services.
#
# Cluster 8 - Google:
# This cluster includes material-design-icons, guava, zx, styleguide, leveldb, googletest from Google organization focused on various tools, libraries, and guidelines by Google.
#
# Cluster 9 - TensorFlow:
# Repositories tensorflow, docs, community, in TensorFlow organization revolve around TensorFlow, its documentation, and its community guidelines.
#
# Cluster 10 - OpenAI:
# openai-cookbook, whisper, evals, openai-python, tiktoken, and openai-node in OpenAI organization are dedicated to the development of the OpenAI API and related components.
#
# Other clusters can be formed in similar manner such as Zcash, OffchainLabs, Layr-Labs, matter-labs, solana-labs, brave, filecoin-projects, ipfs, protocol, 0XPolygon, cardano-foundation, near, stellar, dashpay, tezos, algorand, facebookresearch, google-research, and linux. These clusters all revolve around specific organizations and their projects, tools, or products.

# %%
############################################################
###without org name and repo name provided

###results: not entirely based on original orgs, similar to feed in repos name and description
###########################################################



client = OpenAI(api_key='xxxxxxxxxxx')

instruction = '''Based on the content provided, group all repositories into some clusters, and provide a short definition of each cluster. Note that each cluster should contain more than 1 repository. In addition, the topics of repositories in the cluster should be as similar as possible.The repositories are primarily software development repositories.'''

messages = [
      {"role": "system", "content": instruction},
  ]

# Build the prompt to integrate all repo descriptions into it'''

messages = [
      {"role": "system", "content": instruction},
  ]

# Build the prompt to integrate all repo descriptions into it
prompt = ''

for idx, item in enumerate(Information):
  prompt = prompt + f'{item[2]}\n'

# prompt: 'these are ... repo 1 desc is ...; repo 2 ...'
messages.append({"role": "user", 'content': prompt})
completion = client.chat.completions.create(
  model="gpt-4",
  messages=messages,
  seed = 3407
)

import pickle

with open('completion', 'wb') as f:
  pickle.dump(completion, f)

print(completion.choices[0].message.content)
# Out:
# Cluster 1: Python Programming
# -The Python programming language
# -Optional static typing for Python
# -Source code for python.org
# -Python Enhancement Proposals
# -Collection of library stubs for Python, with static types
# -The Python developer's guide
#
# Cluster 2: Rust Programming
# -Empowering everyone to build reliable and efficient software
# -The Rust package manager
# -RFCs for changes to Rust
#
# Cluster 3: Java and JavaScript Programming
# -PDF Reader in JavaScript
# -DEPRECATED - A HTML5/JavaScript multiplayer game experiment
# -Material Design icons by Google
# -Google core libraries for Java
# -A tool for writing better scripts
# -Style guides for Google-originated open-source projects
#
# Cluster 4: SageMath
# -The main repository of SageMath
# -The code for the sagemath.org website
# -Generate the publication pages listing documents citing Sage
# -Emacs front end for SageMath
# -The Sage Cell Server
# -Embed code, results of computations, and plots from the Sage mathematics software suite
#
# Cluster 5: Kubernetes
# -Production-Grade Container Scheduling and Management
# -Enhancements tracking repo for Kubernetes
# -Kubernetes community content
# -Kubernetes website and documentation repo
# -Test infrastructure for the Kubernetes project
# -Kubernetes application example tutorials
#
# Cluster 6: AWS Development
# -Universal Command Line Interface for Amazon Web Services
# -The AWS Serverless Application Model (AWS SAM) transform
# -The AWS Cloud Development Kit
# -Example Jupyter notebooks demonstrating Amazon SageMaker
# -AWS SDK for the Go programming language
#
# Cluster 7: Google Projects
# -GoogleTest - Google Testing and Mocking Framework
# -An Open Source Machine Learning Framework for Everyone
# -TensorFlow documentation
# -Stores documents used by the TensorFlow developer community
# -LevelDB is a fast key-value storage library written at Google
#
# Cluster 8: OpenAI
# -Examples and guides for using the OpenAI API
# -Robust Speech Recognition via Large-Scale Weak Supervision
# -Evals is a framework for evaluating LLMs and LLM systems
# -The official Python library for the OpenAI API
# -tiktoken is a fast BPE tokeniser for use with OpenAI's models
# -The official Node.js / Typescript library for the OpenAI API
#
# Cluster 9: Zcash
# -Zcash - Internet Money
# -The Halo2 zero-knowledge proving system
# -Rust-language assets for Zcash
# -Zcash Improvement Proposals
# -zk-SNARK parameter multi-party computation protocol
# -libsnark: a C++ library for zkSNARK proofs
#
# Cluster 10: IPFS
# -Technical specifications for the IPFS protocol stack
# -Peer-to-peer hypermedia protocol
# -An unobtrusive and user-friendly desktop application for IPFS on Windows, Mac and Linux
# -Browser extension that simplifies access to IPFS resources on the web
# -An IPFS implementation in Go
# -An implementation of IPFS in JavaScript
#
# Cluster 11: Algorand
# -Algorand's official implementation in Go
# -The official JavaScript SDK for Algorand
# -Algorand Smart Contracts in Python
# -Algorand Python SDK
# -Algorand node sandbox
# -Algorand Golang SDK
#
# Cluster 12: Facebook AI
# -The repository provides code for running inference with the SegmentAnything Model (SAM), links for downloading the trained model checkpoints, and example notebooks that show how to use the model
# -Facebook AI Research Sequence-to-Sequence Toolkit written in Python
# -Detectron2 is a platform for object detection, segmentation and other visual recognition tasks
# -A library for efficient similarity search and clustering of dense vectors
# -FAIR's research platform for object detection research, implementing popular algorithms like Mask R-CNN and RetinaNet
# -Library for fast text representation and classification.

# %%
#########################################################
###with clustering instruction, with org name provided

###result: cluster based on original orgs
########################################################

client = OpenAI(api_key='xxxxxxxxxxxxxxxxxxxx')

instruction = '''Based on the content provided, group all repositories into some clusters based on primary technological domain or application area that each repository contributes to, instead of basing on organization names only, and provide a short definition of each cluster. Note that each cluster should contain more than 1 repository. In addition, the topics of repositories in the cluster should be as similar as possible.The repositories are primarily software development repositories.'''

messages = [
      {"role": "system", "content": instruction},
  ]

# Build the prompt to integrate all repo descriptions into it'''

messages = [
      {"role": "system", "content": instruction},
  ]

# Build the prompt to integrate all repo descriptions into it
prompt = ''

for idx, item in enumerate(Information):
  prompt = prompt + f'{item[1]}:{item[2]} and it is under organization named {item[0]}'

# prompt: 'these are ... repo 1 desc is ...; repo 2 ...'
messages.append({"role": "user", 'content': prompt})
completion = client.chat.completions.create(
  model="gpt-4",
  messages=messages,
  seed = 3407
)

import pickle

with open('completion', 'wb') as f:
  pickle.dump(completion, f)

print(completion.choices[0].message.content)
# Out:
# Cluster 1: Python Development
# Primary technological domain: Python Programming
# Repositories included: cpython, mypy, pythondotorg, peps, typeshed, devguide
# It represents repositories contributing to Python programming language, its static typing, and related guides and enhancements.
#
# Cluster 2: Rust Development
# Primary technological domain: Rust Programming
# Repositories included: rust, cargo, rfcs
# These repositories mainly contribute to the development and efficient use of Rust programming language.
#
# Cluster 3: JavaScript/Open Source Software from Mozilla
# Primary technological domain: Open Source Applications and JavaScript
# Repositories included: pdf.js, DeepSpeech, send, BrowserQuest, TTS, nunjucks
# This cluster embodies repositories featuring different JavaScript-based open source applications built by the Mozilla organization.
#
# Cluster 4: SageMath Development
# Primary technological domain: Mathematical Software
# Repositories included: sage, website, publications, sage-shell-mode, sagecell, sagetex
# These repositories mainly focus on SageMath, an open-source mathematical software and its associated guides and environments.
#
# Cluster 5: Kubernetes Development
# Primary technological domain: Containerization, Container Orchestration
# Repositories included: kubernetes, enhancements, community, website, test-infra, examples
# These repositories contribute towards Kubernetes, a container orchestration system.
#
# Cluster 6: AWS Development
# Primary technological domain: Cloud services and Machine Learning
# Repositories included: aws-cli, serverless-application-model, aws-cdk, amazon-sagemaker-examples, s2n-tls, aws-sdk-go-v2
# This cluster includes repositories dedicated to tools and services in Amazon Web Services (AWS) and its associated machine learning models.
#
# Cluster 7: Google Open-Source Projects
# Primary technological domain: Web Development/Programming Style/Database
# Repositories included: material-design-icons, guava, zx, styleguide, leveldb, googletest
# These repositories contribute to various Google-originated projects like designing, programming style guide, and database.
#
# Cluster 8: TensorFlow Development
# Primary technological domain: Machine Learning
# Repositories included: tensorflow, docs, community
# Repositories in this cluster are dedicated to TensorFlow, a popular machine learning framework.
#
# Cluster 9: OpenAI Development
# Primary technological domain: Artificial Intelligence
# Repositories included: openai-cookbook, whisper, evals, openai-python, tiktoken, openai-node
# This cluster includes repositories from OpenAI that are dedicated to different aspects of Artificial Intelligence.
#
# Cluster 10: Cryptocurrency and Blockchain
# Primary technological domain: Cryptocurrency, Blockchain
# Repositories included: zcash, halo2, librustzcash, zips, mpc, libsnark, nitro, token-bridge-contracts, arbitrum-sdk, arbitrum-tutorials, arbitrum-token-bridge, arbitrum-docs, optimism, specs, docs, community-hub, OPerating-manual, ecosystem-contributions, eigenlayer-contracts, incredible-squaring-avs, eigenda, eigenda-operator-setup, eigenlayer-cli, eigenlayer-middleware, zksync-era, era-contracts, era-sync_vm, awesome-zero-knowledge-proofs, solana-program-library, solana, brave-browser, brave-core, adblock-rust, goggles-quickstart, community, FIPs, lotus, rust-fil-proofs, builtin-actors, ref-fvm, specs, ipfs, ipfs-desktop, ipfs-companion, kubo, helia, arg, research, research-grants, ResNetLab, polygon-edge, fx-portal, cdk-validium-node, chain-indexer-framework, polygon-docs, account-binary-search-tree, CIPs, nearcore, NEPs, core-contracts, near-api-js, create-near-app, near-cli-rs, stellar-protocol, stellar-core, js-stellar-sdk, rs-soroban-sdk, soroban-rpc, soroban-cli, dash, platform, grovedb, tenderdash, dash-wallet, dashwallet-ios, tezos-mirror, go-algorand, js-algorand-sdk, pyteal, py-algorand-sdk, sandbox, go-algorand-sdk
# This cluster represents repositories related to cryptocurrencies like Zcash, Bitcoin, Ethereum, Algorand etc. and their respective blockchain technologies.
#
# Cluster 11: Facebook Research Projects
# Primary technological domain: Machine Learning and AI Research
# Repositories included: segment-anything, fairseq, detectron2, faiss, Detectron, fastText
# This cluster is comprised of repositories focused on AI research projects conducted by Facebook.
#
# Cluster 12: Google Research Project
# Primary technological domain: Web Development / Database Development
# Repositories included: google-research
# This cluster includes repositories related to research on Google products.
#
# Cluster 13: Linux Kernel Development
# Primary technological domain: Operating System
# Repositories included: linux
# This cluster is dedicated to the Linux operating system kernel.
